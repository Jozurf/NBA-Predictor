# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv("nba_games_with_player_data.csv", index_col=0)
#sort by date so the previous values always already happen
df = df.sort_values("date")
#resetting the column number
df = df.reset_index(drop=True)

# %%
#deleting/adding columns
df=df.drop(["index_opp", "+/-"], axis=1)
df["won_opp"] = ~df["won"]
df=df.copy()
#filling up the NaN values
extra = ["won_opp", "home", "home_opp", "total", "total_opp", "season", 'date', 'team', 'team_opp', 'won']
away_players_columns = [col for col in df.columns if col.endswith('_opp') and col not in extra]
home_players_columns = [col for col in df.columns if '_opp' not in col and col not in extra]

#fill missing rows with their previous performance and if no performance, then fill with 0
def fill_missing(team):
    filled = team.loc[:,home_players_columns].ffill()
    filled = filled.fillna(0)
    return filled
df_home_fill=df.groupby(["team"], group_keys=False).apply(fill_missing)

def fill_missing_opp(team):
    filled = team.loc[:,away_players_columns].ffill()
    filled = filled.fillna(0)
    return filled
df_away_fill=df.groupby(["team_opp"], group_keys=False).apply(fill_missing_opp)

# %%
#reset df
df=pd.concat([df_home_fill, df_away_fill, df[extra]], axis=1)
df = df.copy()

# %%
team_cols = df.columns[~df.columns.str.contains('_')]
team_opp_columns = [f'{col}_opp' for col in team_cols]

# %%
extra = ["date_opp", "season_opp"]

# %%
team_df_cols = list(team_cols) + list(team_opp_columns)

# %%
team_df_cols = [col for col in team_df_cols if col not in extra]

# %%
team_df_cols
# Out:
# ['fg',
#  'fga',
#  'fg%',
#  '3p',
#  '3pa',
#  '3p%',
#  'ft',
#  'fta',
#  'ft%',
#  'orb',
#  'drb',
#  'trb',
#  'ast',
#  'stl',
#  'blk',
#  'tov',
#  'pf',
#  'pts',
#  'ts%',
#  'efg%',
#  '3par',
#  'ftr',
#  'orb%',
#  'drb%',
#  'trb%',
#  'ast%',
#  'stl%',
#  'blk%',
#  'tov%',
#  'usg%',
#  'ortg',
#  'drtg',
#  'home',
#  'total',
#  'season',
#  'date',
#  'team',
#  'won',
#  'fg_opp',
#  'fga_opp',
#  'fg%_opp',
#  '3p_opp',
#  '3pa_opp',
#  '3p%_opp',
#  'ft_opp',
#  'fta_opp',
#  'ft%_opp',
#  'orb_opp',
#  'drb_opp',
#  'trb_opp',
#  'ast_opp',
#  'stl_opp',
#  'blk_opp',
#  'tov_opp',
#  'pf_opp',
#  'pts_opp',
#  'ts%_opp',
#  'efg%_opp',
#  '3par_opp',
#  'ftr_opp',
#  'orb%_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'ast%_opp',
#  'stl%_opp',
#  'blk%_opp',
#  'tov%_opp',
#  'usg%_opp',
#  'ortg_opp',
#  'drtg_opp',
#  'home_opp',
#  'total_opp',
#  'team_opp',
#  'won_opp']

# %%
print("+/-" in df.columns)
# Out:
# False

# %%
team_df = df[team_df_cols]

# %%
team_df
# Out:
#          fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb  ...  \
# 0      37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  ...
# 1      37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800   7.0  ...
# 2      38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  ...
# 3      37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696   7.0  ...
# 4      35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  ...
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...  ...
# 20407  34.0  92.0  0.370  11.0  35.0  0.314  15.0  19.0  0.789  10.0  ...
# 20408  39.0  79.0  0.494  14.0  28.0  0.500  16.0  21.0  0.762   5.0  ...
# 20409  35.0  78.0  0.449   8.0  25.0  0.320  17.0  20.0  0.850   8.0  ...
# 20410  33.0  96.0  0.344   9.0  35.0  0.257  14.0  16.0  0.875  11.0  ...
# 20411  38.0  84.0  0.452   5.0  28.0  0.179  13.0  23.0  0.565  11.0  ...
#
#        stl%_opp  blk%_opp  tov%_opp  usg%_opp  ortg_opp  drtg_opp  home_opp  \
# 0           9.4       6.0      14.5     100.0      98.6     111.2         0
# 1           5.2       5.5      12.3     100.0     111.2      98.6         1
# 2           6.0      15.4      11.8     100.0      97.5      95.5         0
# 3           5.0      10.3       9.0     100.0      95.5      97.5         1
# 4           8.0      10.8      15.9     100.0     110.9      94.9         0
# ...         ...       ...       ...       ...       ...       ...       ...
# 20407       3.3       8.8      12.4     100.0     120.4     103.8         1
# 20408       2.3       5.9      13.9     100.0     107.2     121.9         0
# 20409      12.4      13.2       6.4     100.0     121.9     107.2         1
# 20410       6.2      11.5      12.9     100.0      97.8      92.6         0
# 20411       9.4      12.5       7.2     100.0      92.6      97.8         1
#
#        total_opp  team_opp  won_opp
# 0             94       ATL    False
# 1            106       DET     True
# 2             97       CHI     True
# 3             95       CLE    False
# 4            111       GSW     True
# ...          ...       ...      ...
# 20407        109       DEN     True
# 20408         95       MIA    False
# 20409        108       DEN     True
# 20410         94       DEN     True
# 20411         89       MIA    False
#
# [20412 rows x 74 columns]

# %%
df = df.copy()
team_df = team_df.copy()

# %%
# creating new columns net rtng, Assist turnover, Rebound Deferential & b2b
team_df["net_rtg"] = team_df["ortg"] - team_df["drtg"]
team_df["net_rtg_opp"] = team_df["ortg_opp"] - team_df["drtg_opp"]

team_df["ast_tov"] = team_df["ast"] / team_df["tov"]
team_df["ast_tov_opp"] = team_df["ast_opp"] / team_df["tov_opp"]

team_df["rb_diff"] = team_df["trb"] - team_df["trb_opp"]
team_df["rb_diff_opp"] = team_df["trb_opp"] - team_df["trb"]

# %%
team_df['prev_game_date'] = team_df.groupby('team')['date'].shift(1)
team_df['prev_game_date_opp'] = team_df.groupby('team_opp')['date'].shift(1)
timeDelta = pd.to_datetime(team_df["date"], format="%Y-%m-%d") - pd.to_datetime(team_df["prev_game_date"], format="%Y-%m-%d")
timeDelta_opp = pd.to_datetime(team_df["date"], format="%Y-%m-%d") - pd.to_datetime(team_df['prev_game_date_opp'], format="%Y-%m-%d")
team_df["b2b"] = timeDelta.dt.days == 1
team_df["b2b_opp"] = timeDelta_opp.dt.days == 1

team_df[["b2b", "b2b_opp"]] = team_df[["b2b", "b2b_opp"]].astype(int, errors="ignore")

# %%
team_df = team_df[team_df["home"] == 1]

# %%
team_df.reset_index(drop=True)
# Out:
#          fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb  ...  \
# 0      37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  ...
# 1      38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  ...
# 2      35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  ...
# 3      45.0  93.0  0.484   5.0  15.0  0.333  11.0  13.0  0.846   7.0  ...
# 4      33.0  84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  15.0  ...
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...  ...
# 10201  39.0  96.0  0.406  13.0  39.0  0.333   2.0   2.0  1.000  11.0  ...
# 10202  38.0  78.0  0.487  17.0  35.0  0.486  18.0  20.0  0.900   8.0  ...
# 10203  41.0  80.0  0.513   5.0  18.0  0.278  22.0  27.0  0.815  13.0  ...
# 10204  39.0  79.0  0.494  14.0  28.0  0.500  16.0  21.0  0.762   5.0  ...
# 10205  33.0  96.0  0.344   9.0  35.0  0.257  14.0  16.0  0.875  11.0  ...
#
#        net_rtg  net_rtg_opp   ast_tov  ast_tov_opp  rb_diff  rb_diff_opp  \
# 0         12.6        -12.6  1.533333     1.466667     19.0        -19.0
# 1         -2.0          2.0  2.600000     1.000000      3.0         -3.0
# 2        -16.0         16.0  1.166667     1.450000    -23.0         23.0
# 3         -5.9          5.9  1.692308     1.105263     -9.0          9.0
# 4          1.1         -1.1  1.000000     1.428571     -7.0          7.0
# ...        ...          ...       ...          ...      ...          ...
# 10201    -12.1         12.1  3.250000     2.900000     -2.0          2.0
# 10202      3.5         -3.5  2.545455     1.769231     -7.0          7.0
# 10203     16.6        -16.6  2.153846     5.000000     25.0        -25.0
# 10204     14.7        -14.7  4.333333     1.642857     -3.0          3.0
# 10205     -5.2          5.2  2.250000     1.500000    -13.0         13.0
#
#        prev_game_date  prev_game_date_opp  b2b  b2b_opp
# 0                 NaN                 NaN    0        0
# 1                 NaN                 NaN    0        0
# 2                 NaN                 NaN    0        0
# 3                 NaN                 NaN    0        0
# 4                 NaN                 NaN    0        0
# ...               ...                 ...  ...      ...
# 10201      2023-05-29          2023-05-22    0        0
# 10202      2023-06-01          2023-06-01    0        0
# 10203      2023-06-04          2023-06-04    0        0
# 10204      2023-06-07          2023-06-07    0        0
# 10205      2023-06-09          2023-06-09    0        0
#
# [10206 rows x 84 columns]

# %%
team_df.to_csv("team_features.csv")

# %%
player_cols = [col for col in df.columns if col not in team_df_cols]

# %%
cols_to_add = ["team", "team_opp","date", "season", "won", "home"]

# %%
player_cols = player_cols + cols_to_add

# %%
player_df = df[player_cols]

# %%
player_df = player_df[player_df["home"] == 1]

# %%
player_df.to_csv("player_features.csv")

# %% [markdown]
# # Rolling the team averages

# %% [markdown]
# ### import team features csv from here

# %%
team_df = pd.read_csv("team_features.csv")

# %%
team_df
# Out:
#        Unnamed: 0    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  \
# 0               0  37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769
# 1               2  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588
# 2               4  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704
# 3               6  45.0  93.0  0.484   5.0  15.0  0.333  11.0  13.0  0.846
# 4               8  33.0  84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600
# ...           ...   ...   ...    ...   ...   ...    ...   ...   ...    ...
# 10201       20402  39.0  96.0  0.406  13.0  39.0  0.333   2.0   2.0  1.000
# 10202       20404  38.0  78.0  0.487  17.0  35.0  0.486  18.0  20.0  0.900
# 10203       20406  41.0  80.0  0.513   5.0  18.0  0.278  22.0  27.0  0.815
# 10204       20408  39.0  79.0  0.494  14.0  28.0  0.500  16.0  21.0  0.762
# 10205       20410  33.0  96.0  0.344   9.0  35.0  0.257  14.0  16.0  0.875
#
#        ...  net_rtg  net_rtg_opp   ast_tov  ast_tov_opp  rb_diff  rb_diff_opp  \
# 0      ...     12.6        -12.6  1.533333     1.466667     19.0        -19.0
# 1      ...     -2.0          2.0  2.600000     1.000000      3.0         -3.0
# 2      ...    -16.0         16.0  1.166667     1.450000    -23.0         23.0
# 3      ...     -5.9          5.9  1.692308     1.105263     -9.0          9.0
# 4      ...      1.1         -1.1  1.000000     1.428571     -7.0          7.0
# ...    ...      ...          ...       ...          ...      ...          ...
# 10201  ...    -12.1         12.1  3.250000     2.900000     -2.0          2.0
# 10202  ...      3.5         -3.5  2.545455     1.769231     -7.0          7.0
# 10203  ...     16.6        -16.6  2.153846     5.000000     25.0        -25.0
# 10204  ...     14.7        -14.7  4.333333     1.642857     -3.0          3.0
# 10205  ...     -5.2          5.2  2.250000     1.500000    -13.0         13.0
#
#        prev_game_date  prev_game_date_opp  b2b  b2b_opp
# 0                 NaN                 NaN    0        0
# 1                 NaN                 NaN    0        0
# 2                 NaN                 NaN    0        0
# 3                 NaN                 NaN    0        0
# 4                 NaN                 NaN    0        0
# ...               ...                 ...  ...      ...
# 10201      2023-05-29          2023-05-22    0        0
# 10202      2023-06-01          2023-06-01    0        0
# 10203      2023-06-04          2023-06-04    0        0
# 10204      2023-06-07          2023-06-07    0        0
# 10205      2023-06-09          2023-06-09    0        0
#
# [10206 rows x 85 columns]

# %%
team_df = team_df.drop(["prev_game_date", "prev_game_date_opp", "Unnamed: 0"], axis=1)

# %%
home_team_cols = team_df.columns[~team_df.columns.str.contains('_opp')]

# %%
home_team_cols
# Out:
# Index(['fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%', 'orb',
#        'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'ts%', 'efg%',
#        '3par', 'ftr', 'orb%', 'drb%', 'trb%', 'ast%', 'stl%', 'blk%', 'tov%',
#        'usg%', 'ortg', 'drtg', 'home', 'total', 'season', 'date', 'team',
#        'won', 'net_rtg', 'ast_tov', 'rb_diff', 'b2b'],
#       dtype='object')

# %%
# select rolling columns for home  (done)
# create a df of rolling columns for home
no_roll_columns = ["date", "home", "b2b", "team", "season"]
home_team_cols = [col for col in home_team_cols if col not in no_roll_columns]
df_home_rolling = team_df[home_team_cols]

# append those rolling cols to team_df
# select rolling columns for away
# create a df of rolling columns for away
# append those rolling cols to team_df
# collectively selecting rolling cols

# %%
# Out:
# ['fg',
#  'fga',
#  'fg%',
#  '3p',
#  '3pa',
#  '3p%',
#  'ft',
#  'fta',
#  'ft%',
#  'orb',
#  'drb',
#  'trb',
#  'ast',
#  'stl',
#  'blk',
#  'tov',
#  'pf',
#  'pts',
#  'ts%',
#  'efg%',
#  '3par',
#  'ftr',
#  'orb%',
#  'drb%',
#  'trb%',
#  'ast%',
#  'stl%',
#  'blk%',
#  'tov%',
#  'usg%',
#  'ortg',
#  'drtg',
#  'total',
#  'won',
#  'net_rtg',
#  'ast_tov',
#  'rb_diff']

# %%
window_size = 82 
df_home_rolling = team_df[home_team_cols + ["team", "season"]]
def find_team_averages(team):
    rolling = team[home_team_cols].shift(1).rolling(window_size, min_periods=1).mean()
    return rolling
    #using rolling average on team
df_home_rolling = df_home_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
df_home_rolling = df_home_rolling.add_suffix(f'_{window_size}')

# %%
df_home_rolling = df_home_rolling.reset_index(drop=True)

# %%
df_home_rolling
# Out:
#            fg_82     fga_82    fg%_82      3p_82     3pa_82    3p%_82  \
# 0            NaN        NaN       NaN        NaN        NaN       NaN
# 1            NaN        NaN       NaN        NaN        NaN       NaN
# 2            NaN        NaN       NaN        NaN        NaN       NaN
# 3            NaN        NaN       NaN        NaN        NaN       NaN
# 4            NaN        NaN       NaN        NaN        NaN       NaN
# ...          ...        ...       ...        ...        ...       ...
# 10201  39.450980  86.137255  0.458451  12.333333  35.960784  0.343373
# 10202  39.442308  86.326923  0.457442  12.346154  36.019231  0.343173
# 10203  42.812500  86.354167  0.497292  11.270833  30.729167  0.364063
# 10204  42.775510  86.224490  0.497612  11.142857  30.469388  0.362306
# 10205  39.415094  86.169811  0.458000  12.433962  36.000000  0.345868
#
#            ft_82     fta_82    ft%_82    orb_82  ...   blk%_82    tov%_82  \
# 0            NaN        NaN       NaN       NaN  ...       NaN        NaN
# 1            NaN        NaN       NaN       NaN  ...       NaN        NaN
# 2            NaN        NaN       NaN       NaN  ...       NaN        NaN
# 3            NaN        NaN       NaN       NaN  ...       NaN        NaN
# 4            NaN        NaN       NaN       NaN  ...       NaN        NaN
# ...          ...        ...       ...       ...  ...       ...        ...
# 10201  17.352941  21.627451  0.802275  9.411765  ...  6.168627  11.831373
# 10202  17.057692  21.250000  0.806077  9.442308  ...  6.198077  11.750000
# 10203  16.083333  20.625000  0.776625  9.833333  ...  7.814583  12.539583
# 10204  16.204082  20.755102  0.777408  9.897959  ...  7.834694  12.536735
# 10205  17.075472  21.226415  0.807849  9.415094  ...  6.241509  11.739623
#
#        usg%_82     ortg_82     drtg_82    total_82    won_82  net_rtg_82  \
# 0          NaN         NaN         NaN         NaN       NaN         NaN
# 1          NaN         NaN         NaN         NaN       NaN         NaN
# 2          NaN         NaN         NaN         NaN       NaN         NaN
# 3          NaN         NaN         NaN         NaN       NaN         NaN
# 4          NaN         NaN         NaN         NaN       NaN         NaN
# ...        ...         ...         ...         ...       ...         ...
# 10201    100.0  112.615686  113.941176  108.588235  0.450980   -1.325490
# 10202    100.0  112.417308  113.950000  108.288462  0.442308   -1.532692
# 10203    100.0  116.368750  118.420833  112.979167  0.479167   -2.052083
# 10204    100.0  116.451020  118.122449  112.897959  0.489796   -1.671429
# 10205    100.0  112.707547  114.145283  108.339623  0.452830   -1.437736
#
#        ast_tov_82  rb_diff_82
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
# ...           ...         ...
# 10201    2.045027   -2.921569
# 10202    2.068199   -2.903846
# 10203    2.275350    0.145833
# 10204    2.272871    0.653061
# 10205    2.077204   -2.981132
#
# [10206 rows x 37 columns]

# %%
#adding columns to make a wide dataframe
team_df=pd.concat([team_df, df_home_rolling], axis=1)

# %%
away_team_cols = [f'{col}_opp' for col in home_team_cols]

# %%
away_team_cols
# Out:
# ['fg_opp',
#  'fga_opp',
#  'fg%_opp',
#  '3p_opp',
#  '3pa_opp',
#  '3p%_opp',
#  'ft_opp',
#  'fta_opp',
#  'ft%_opp',
#  'orb_opp',
#  'drb_opp',
#  'trb_opp',
#  'ast_opp',
#  'stl_opp',
#  'blk_opp',
#  'tov_opp',
#  'pf_opp',
#  'pts_opp',
#  'ts%_opp',
#  'efg%_opp',
#  '3par_opp',
#  'ftr_opp',
#  'orb%_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'ast%_opp',
#  'stl%_opp',
#  'blk%_opp',
#  'tov%_opp',
#  'usg%_opp',
#  'ortg_opp',
#  'drtg_opp',
#  'total_opp',
#  'won_opp',
#  'net_rtg_opp',
#  'ast_tov_opp',
#  'rb_diff_opp']

# %%
window_size = 82 
df_away_rolling = team_df[away_team_cols + ["team_opp", "season"]]
def find_team_averages_away(team):
    rolling = team[away_team_cols].shift(1).rolling(window_size, min_periods=1).mean()
    return rolling
    #using rolling average on team
df_away_rolling = df_away_rolling.groupby(["team_opp", "season"], group_keys=False).apply(find_team_averages_away)
df_away_rolling = df_away_rolling.add_suffix(f'_{window_size}')

# %%
df_away_rolling
# Out:
#        fg_opp_82  fga_opp_82  fg%_opp_82  3p_opp_82  3pa_opp_82  3p%_opp_82  \
# 0            NaN         NaN         NaN        NaN         NaN         NaN
# 1            NaN         NaN         NaN        NaN         NaN         NaN
# 2            NaN         NaN         NaN        NaN         NaN         NaN
# 3            NaN         NaN         NaN        NaN         NaN         NaN
# 4            NaN         NaN         NaN        NaN         NaN         NaN
# ...          ...         ...         ...        ...         ...         ...
# 10201  44.224490   87.040816    0.508857  12.448980   31.734694    0.390367
# 10202  44.140000   86.880000    0.508800  12.360000   31.640000    0.388480
# 10203  39.392157   84.784314    0.465529  11.921569   33.078431    0.362706
# 10204  39.288462   84.923077    0.463692  11.903846   33.115385    0.361769
# 10205  44.039216   86.647059    0.509020  12.333333   31.568627    0.388569
#
#        ft_opp_82  fta_opp_82  ft%_opp_82  orb_opp_82  ...  blk%_opp_82  \
# 0            NaN         NaN         NaN         NaN  ...          NaN
# 1            NaN         NaN         NaN         NaN  ...          NaN
# 2            NaN         NaN         NaN         NaN  ...          NaN
# 3            NaN         NaN         NaN         NaN  ...          NaN
# 4            NaN         NaN         NaN         NaN  ...          NaN
# ...          ...         ...         ...         ...  ...          ...
# 10201  17.836735   23.938776    0.747735   10.469388  ...     8.332653
# 10202  17.800000   23.860000    0.748780   10.380000  ...     8.306000
# 10203  20.196078   23.764706    0.844961    9.725490  ...     6.574510
# 10204  20.096154   23.673077    0.843885    9.730769  ...     6.540385
# 10205  17.823529   23.823529    0.751039   10.352941  ...     8.235294
#
#        tov%_opp_82  usg%_opp_82  ortg_opp_82  drtg_opp_82  total_opp_82  \
# 0              NaN          NaN          NaN          NaN           NaN
# 1              NaN          NaN          NaN          NaN           NaN
# 2              NaN          NaN          NaN          NaN           NaN
# 3              NaN          NaN          NaN          NaN           NaN
# 4              NaN          NaN          NaN          NaN           NaN
# ...            ...          ...          ...          ...           ...
# 10201    11.600000        100.0   121.420408   111.138776    118.734694
# 10202    11.572000        100.0   121.280000   110.962000    118.440000
# 10203    11.358824        100.0   116.194118   114.013725    110.901961
# 10204    11.213462        100.0   115.955769   114.136538    110.576923
# 10205    11.605882        100.0   121.339216   111.292157    118.235294
#
#        won_opp_82  net_rtg_opp_82  ast_tov_opp_82  rb_diff_opp_82
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
# ...           ...             ...             ...             ...
# 10201    0.857143       10.281633        2.367678        5.306122
# 10202    0.860000       10.318000        2.378324        5.240000
# 10203    0.666667        2.180392        2.135988       -0.156863
# 10204    0.653846        1.819231        2.191065       -0.634615
# 10205    0.843137       10.047059        2.366381        5.274510
#
# [10206 rows x 37 columns]

# %%
team_df
# Out:
#          fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb  ...  \
# 0      37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  ...
# 1      38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  ...
# 2      35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  ...
# 3      45.0  93.0  0.484   5.0  15.0  0.333  11.0  13.0  0.846   7.0  ...
# 4      33.0  84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  15.0  ...
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...  ...
# 10201  39.0  96.0  0.406  13.0  39.0  0.333   2.0   2.0  1.000  11.0  ...
# 10202  38.0  78.0  0.487  17.0  35.0  0.486  18.0  20.0  0.900   8.0  ...
# 10203  41.0  80.0  0.513   5.0  18.0  0.278  22.0  27.0  0.815  13.0  ...
# 10204  39.0  79.0  0.494  14.0  28.0  0.500  16.0  21.0  0.762   5.0  ...
# 10205  33.0  96.0  0.344   9.0  35.0  0.257  14.0  16.0  0.875  11.0  ...
#
#         blk%_82    tov%_82  usg%_82     ortg_82     drtg_82    total_82  \
# 0           NaN        NaN      NaN         NaN         NaN         NaN
# 1           NaN        NaN      NaN         NaN         NaN         NaN
# 2           NaN        NaN      NaN         NaN         NaN         NaN
# 3           NaN        NaN      NaN         NaN         NaN         NaN
# 4           NaN        NaN      NaN         NaN         NaN         NaN
# ...         ...        ...      ...         ...         ...         ...
# 10201  6.168627  11.831373    100.0  112.615686  113.941176  108.588235
# 10202  6.198077  11.750000    100.0  112.417308  113.950000  108.288462
# 10203  7.814583  12.539583    100.0  116.368750  118.420833  112.979167
# 10204  7.834694  12.536735    100.0  116.451020  118.122449  112.897959
# 10205  6.241509  11.739623    100.0  112.707547  114.145283  108.339623
#
#          won_82  net_rtg_82  ast_tov_82  rb_diff_82
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# ...         ...         ...         ...         ...
# 10201  0.450980   -1.325490    2.045027   -2.921569
# 10202  0.442308   -1.532692    2.068199   -2.903846
# 10203  0.479167   -2.052083    2.275350    0.145833
# 10204  0.489796   -1.671429    2.272871    0.653061
# 10205  0.452830   -1.437736    2.077204   -2.981132
#
# [10206 rows x 119 columns]

# %%
team_df=pd.concat([team_df, df_away_rolling], axis=1)

# %%
team_df
# Out:
#          fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%   orb  ...  \
# 0      37.0  96.0  0.385  12.0  29.0  0.414  20.0  26.0  0.769  23.0  ...
# 1      38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  11.0  ...
# 2      35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704   8.0  ...
# 3      45.0  93.0  0.484   5.0  15.0  0.333  11.0  13.0  0.846   7.0  ...
# 4      33.0  84.0  0.393   7.0  28.0  0.250  15.0  25.0  0.600  15.0  ...
# ...     ...   ...    ...   ...   ...    ...   ...   ...    ...   ...  ...
# 10201  39.0  96.0  0.406  13.0  39.0  0.333   2.0   2.0  1.000  11.0  ...
# 10202  38.0  78.0  0.487  17.0  35.0  0.486  18.0  20.0  0.900   8.0  ...
# 10203  41.0  80.0  0.513   5.0  18.0  0.278  22.0  27.0  0.815  13.0  ...
# 10204  39.0  79.0  0.494  14.0  28.0  0.500  16.0  21.0  0.762   5.0  ...
# 10205  33.0  96.0  0.344   9.0  35.0  0.257  14.0  16.0  0.875  11.0  ...
#
#        blk%_opp_82  tov%_opp_82  usg%_opp_82  ortg_opp_82  drtg_opp_82  \
# 0              NaN          NaN          NaN          NaN          NaN
# 1              NaN          NaN          NaN          NaN          NaN
# 2              NaN          NaN          NaN          NaN          NaN
# 3              NaN          NaN          NaN          NaN          NaN
# 4              NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 10201     8.332653    11.600000        100.0   121.420408   111.138776
# 10202     8.306000    11.572000        100.0   121.280000   110.962000
# 10203     6.574510    11.358824        100.0   116.194118   114.013725
# 10204     6.540385    11.213462        100.0   115.955769   114.136538
# 10205     8.235294    11.605882        100.0   121.339216   111.292157
#
#        total_opp_82  won_opp_82  net_rtg_opp_82  ast_tov_opp_82  \
# 0               NaN         NaN             NaN             NaN
# 1               NaN         NaN             NaN             NaN
# 2               NaN         NaN             NaN             NaN
# 3               NaN         NaN             NaN             NaN
# 4               NaN         NaN             NaN             NaN
# ...             ...         ...             ...             ...
# 10201    118.734694    0.857143       10.281633        2.367678
# 10202    118.440000    0.860000       10.318000        2.378324
# 10203    110.901961    0.666667        2.180392        2.135988
# 10204    110.576923    0.653846        1.819231        2.191065
# 10205    118.235294    0.843137       10.047059        2.366381
#
#        rb_diff_opp_82
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 10201        5.306122
# 10202        5.240000
# 10203       -0.156863
# 10204       -0.634615
# 10205        5.274510
#
# [10206 rows x 156 columns]

# %%
features_to_train = list(df_home_rolling.columns) + list(df_away_rolling.columns)

# %%
features_to_train
# Out:
# ['fg_82',
#  'fga_82',
#  'fg%_82',
#  '3p_82',
#  '3pa_82',
#  '3p%_82',
#  'ft_82',
#  'fta_82',
#  'ft%_82',
#  'orb_82',
#  'drb_82',
#  'trb_82',
#  'ast_82',
#  'stl_82',
#  'blk_82',
#  'tov_82',
#  'pf_82',
#  'pts_82',
#  'ts%_82',
#  'efg%_82',
#  '3par_82',
#  'ftr_82',
#  'orb%_82',
#  'drb%_82',
#  'trb%_82',
#  'ast%_82',
#  'stl%_82',
#  'blk%_82',
#  'tov%_82',
#  'usg%_82',
#  'ortg_82',
#  'drtg_82',
#  'total_82',
#  'won_82',
#  'net_rtg_82',
#  'ast_tov_82',
#  'rb_diff_82',
#  'fg_opp_82',
#  'fga_opp_82',
#  'fg%_opp_82',
#  '3p_opp_82',
#  '3pa_opp_82',
#  '3p%_opp_82',
#  'ft_opp_82',
#  'fta_opp_82',
#  'ft%_opp_82',
#  'orb_opp_82',
#  'drb_opp_82',
#  'trb_opp_82',
#  'ast_opp_82',
#  'stl_opp_82',
#  'blk_opp_82',
#  'tov_opp_82',
#  'pf_opp_82',
#  'pts_opp_82',
#  'ts%_opp_82',
#  'efg%_opp_82',
#  '3par_opp_82',
#  'ftr_opp_82',
#  'orb%_opp_82',
#  'drb%_opp_82',
#  'trb%_opp_82',
#  'ast%_opp_82',
#  'stl%_opp_82',
#  'blk%_opp_82',
#  'tov%_opp_82',
#  'usg%_opp_82',
#  'ortg_opp_82',
#  'drtg_opp_82',
#  'total_opp_82',
#  'won_opp_82',
#  'net_rtg_opp_82',
#  'ast_tov_opp_82',
#  'rb_diff_opp_82']

# %%
team_df=team_df.dropna()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
team_df[features_to_train] = scaler.fit_transform(team_df[features_to_train])
# Out:
# C:\Users\cools\AppData\Local\Temp\ipykernel_7596\1580415598.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_df[features_to_train] = scaler.fit_transform(team_df[features_to_train])

# %%
features_to_train=features_to_train + ["b2b", "b2b_opp", "home", "home_opp"]

# %%
list(team_df.columns)
# Out:
# ['fg',
#  'fga',
#  'fg%',
#  '3p',
#  '3pa',
#  '3p%',
#  'ft',
#  'fta',
#  'ft%',
#  'orb',
#  'drb',
#  'trb',
#  'ast',
#  'stl',
#  'blk',
#  'tov',
#  'pf',
#  'pts',
#  'ts%',
#  'efg%',
#  '3par',
#  'ftr',
#  'orb%',
#  'drb%',
#  'trb%',
#  'ast%',
#  'stl%',
#  'blk%',
#  'tov%',
#  'usg%',
#  'ortg',
#  'drtg',
#  'team',
#  'total',
#  'home',
#  'season',
#  'date',
#  'won',
#  'fg_opp',
#  'fga_opp',
#  'fg%_opp',
#  '3p_opp',
#  '3pa_opp',
#  '3p%_opp',
#  'ft_opp',
#  'fta_opp',
#  'ft%_opp',
#  'orb_opp',
#  'drb_opp',
#  'trb_opp',
#  'ast_opp',
#  'stl_opp',
#  'blk_opp',
#  'tov_opp',
#  'pf_opp',
#  'pts_opp',
#  'ts%_opp',
#  'efg%_opp',
#  '3par_opp',
#  'ftr_opp',
#  'orb%_opp',
#  'drb%_opp',
#  'trb%_opp',
#  'ast%_opp',
#  'stl%_opp',
#  'blk%_opp',
#  'tov%_opp',
#  'usg%_opp',
#  'ortg_opp',
#  'drtg_opp',
#  'team_opp',
#  'total_opp',
#  'home_opp',
#  'won_opp',
#  'net_rtg',
#  'net_rtg_opp',
#  'ast_tov',
#  'ast_tov_opp',
#  'rb_diff',
#  'rb_diff_opp',
#  'b2b',
#  'b2b_opp',
#  'fg_82',
#  'fga_82',
#  'fg%_82',
#  '3p_82',
#  '3pa_82',
#  '3p%_82',
#  'ft_82',
#  'fta_82',
#  'ft%_82',
#  'orb_82',
#  'drb_82',
#  'trb_82',
#  'ast_82',
#  'stl_82',
#  'blk_82',
#  'tov_82',
#  'pf_82',
#  'pts_82',
#  'ts%_82',
#  'efg%_82',
#  '3par_82',
#  'ftr_82',
#  'orb%_82',
#  'drb%_82',
#  'trb%_82',
#  'ast%_82',
#  'stl%_82',
#  'blk%_82',
#  'tov%_82',
#  'usg%_82',
#  'ortg_82',
#  'drtg_82',
#  'total_82',
#  'won_82',
#  'net_rtg_82',
#  'ast_tov_82',
#  'rb_diff_82',
#  'fg_opp_82',
#  'fga_opp_82',
#  'fg%_opp_82',
#  '3p_opp_82',
#  '3pa_opp_82',
#  '3p%_opp_82',
#  'ft_opp_82',
#  'fta_opp_82',
#  'ft%_opp_82',
#  'orb_opp_82',
#  'drb_opp_82',
#  'trb_opp_82',
#  'ast_opp_82',
#  'stl_opp_82',
#  'blk_opp_82',
#  'tov_opp_82',
#  'pf_opp_82',
#  'pts_opp_82',
#  'ts%_opp_82',
#  'efg%_opp_82',
#  '3par_opp_82',
#  'ftr_opp_82',
#  'orb%_opp_82',
#  'drb%_opp_82',
#  'trb%_opp_82',
#  'ast%_opp_82',
#  'stl%_opp_82',
#  'blk%_opp_82',
#  'tov%_opp_82',
#  'usg%_opp_82',
#  'ortg_opp_82',
#  'drtg_opp_82',
#  'total_opp_82',
#  'won_opp_82',
#  'net_rtg_opp_82',
#  'ast_tov_opp_82',
#  'rb_diff_opp_82']

# %%
team_df_processed=team_df[features_to_train + ["team", "team_opp", "date", "season", "won"]]

# %%
team_df_processed
# Out:
#           fg_82    fga_82    fg%_82     3p_82    3pa_82    3p%_82     ft_82  \
# 25     0.266667  0.326531  0.290520  0.260870  0.355556  0.334000  0.344828
# 27     0.266667  0.326531  0.290520  0.217391  0.266667  0.334000  0.586207
# 31     0.566667  0.204082  0.733945  0.565217  0.355556  0.834000  0.413793
# 35     0.200000  0.183673  0.321101  0.173913  0.088889  0.460000  0.103448
# 37     0.350000  0.275510  0.428135  0.152174  0.011111  0.539000  0.431034
# ...         ...       ...       ...       ...       ...       ...       ...
# 10201  0.481699  0.370148  0.490676  0.492754  0.532462  0.520745  0.425963
# 10202  0.481410  0.374019  0.487591  0.493311  0.533761  0.520346  0.415782
# 10203  0.593750  0.374575  0.609455  0.446558  0.416204  0.562125  0.382184
# 10204  0.592517  0.371928  0.610435  0.440994  0.410431  0.558612  0.386348
# 10205  0.480503  0.370812  0.489297  0.497129  0.533333  0.525736  0.416396
#
#          fta_82    ft%_82    orb_82  ...  rb_diff_opp_82  b2b  b2b_opp  home  \
# 25     0.432432  0.200000  0.619048  ...        0.367347    0        0     1
# 27     0.540541  0.518000  0.428571  ...        0.020408    0        1     1
# 31     0.297297  0.700000  0.142857  ...        0.510204    0        0     1
# 35     0.162162  0.066000  0.000000  ...        0.122449    1        0     1
# 37     0.378378  0.514000  0.309524  ...        0.326531    1        0     1
# ...         ...       ...       ...  ...             ...  ...      ...   ...
# 10201  0.341282  0.604549  0.352941  ...        0.516451    0        0     1
# 10202  0.331081  0.612154  0.354396  ...        0.515102    0        0     1
# 10203  0.314189  0.553250  0.373016  ...        0.404962    0        0     1
# 10204  0.317705  0.554816  0.376093  ...        0.395212    0        0     1
# 10205  0.330444  0.615698  0.353100  ...        0.515806    0        0     1
#
#        home_opp  team  team_opp        date  season    won
# 25            0   WAS       MIL  2015-10-30    2016   True
# 27            0   CHO       ATL  2015-10-30    2016  False
# 31            0   CHI       DET  2015-10-30    2016  False
# 35            0   BRK       MEM  2015-10-31    2016  False
# 37            0   UTA       IND  2015-10-31    2016   True
# ...         ...   ...       ...         ...     ...    ...
# 10201         0   MIA       DEN  2023-06-01    2023  False
# 10202         0   MIA       DEN  2023-06-04    2023   True
# 10203         0   DEN       MIA  2023-06-07    2023   True
# 10204         0   DEN       MIA  2023-06-09    2023   True
# 10205         0   MIA       DEN  2023-06-12    2023  False
#
# [9903 rows x 83 columns]

# %%
team_df_processed.to_csv("team_df_processed.csv")

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import preprocessing
X = team_df_processed[features_to_train]
y = team_df_processed["won"]
features = X.columns
rf = GradientBoostingClassifier()
rf.fit(X, y)
importances = rf.feature_importances_

# %%
# Create a list of tuples where each tuple contains the feature and its importance
feature_importance_tuples = list(zip(features, importances))

# Sort the list of tuples based on the importance scores in descending order
sorted_feature_importance = sorted(feature_importance_tuples, key=lambda x: x[1], reverse=True)
sorted_feature_importance
# Out:
# [('net_rtg_opp_82', 0.2185614262213244),
#  ('net_rtg_82', 0.13594456769050114),
#  ('won_82', 0.05341947719197078),
#  ('won_opp_82', 0.04806460400138376),
#  ('ast%_opp_82', 0.02277912427775786),
#  ('ts%_82', 0.022057073238688715),
#  ('3par_82', 0.02160557662581929),
#  ('stl%_opp_82', 0.019969967556169373),
#  ('drb_opp_82', 0.019694544576860474),
#  ('3pa_opp_82', 0.019319656011863435),
#  ('ortg_opp_82', 0.017109764008153408),
#  ('b2b', 0.015391015643290895),
#  ('fg%_82', 0.014349787378074122),
#  ('ft%_82', 0.013666850508441537),
#  ('blk_opp_82', 0.01200005734327334),
#  ('3pa_82', 0.01193649330979495),
#  ('orb%_82', 0.011052879143524673),
#  ('ast_tov_82', 0.010940987859296742),
#  ('tov%_opp_82', 0.010872385273003705),
#  ('ast%_82', 0.010558588822690573),
#  ('drb%_opp_82', 0.010488691973624707),
#  ('stl%_82', 0.01039475137267607),
#  ('ast_tov_opp_82', 0.009624203548313193),
#  ('blk%_opp_82', 0.00934808223691359),
#  ('pf_82', 0.009146130982262054),
#  ('fg%_opp_82', 0.00892576942209806),
#  ('drb%_82', 0.008912260925368714),
#  ('blk%_82', 0.00849156343199857),
#  ('trb%_82', 0.008425501088254645),
#  ('pf_opp_82', 0.00817787445977891),
#  ('drtg_82', 0.008137900537696204),
#  ('trb_opp_82', 0.007688401950000288),
#  ('stl_opp_82', 0.007493880131520458),
#  ('orb_82', 0.007478403764524567),
#  ('fga_opp_82', 0.007415019665548501),
#  ('fga_82', 0.00705373587718054),
#  ('rb_diff_opp_82', 0.006938917722780206),
#  ('ft%_opp_82', 0.006834972045461859),
#  ('3p_82', 0.006604561613344062),
#  ('tov_opp_82', 0.006583289110395173),
#  ('fg_82', 0.006506264709021439),
#  ('ortg_82', 0.0064762002565441484),
#  ('3par_opp_82', 0.006239591907360073),
#  ('stl_82', 0.0061586827379668295),
#  ('3p%_82', 0.005693849124053569),
#  ('3p%_opp_82', 0.005635313385927555),
#  ('fg_opp_82', 0.005628404480586992),
#  ('ft_82', 0.005339315774773808),
#  ('trb%_opp_82', 0.005189442675124718),
#  ('tov%_82', 0.00510969936909062),
#  ('blk_82', 0.004576523722131652),
#  ('drtg_opp_82', 0.004433441942479495),
#  ('ts%_opp_82', 0.004383913551739069),
#  ('tov_82', 0.004206470003469851),
#  ('ftr_opp_82', 0.004015129308172022),
#  ('trb_82', 0.0038798988521839576),
#  ('fta_82', 0.0038432476196917998),
#  ('ftr_82', 0.0037347722854498672),
#  ('ast_opp_82', 0.0036401181727963444),
#  ('drb_82', 0.0033931731218555796),
#  ('rb_diff_82', 0.0033131815792805572),
#  ('efg%_opp_82', 0.003292484077217831),
#  ('ast_82', 0.00299713238510087),
#  ('orb_opp_82', 0.0025749883468019906),
#  ('efg%_82', 0.0023887245052960884),
#  ('ft_opp_82', 0.0022201957321493935),
#  ('orb%_opp_82', 0.002130606039201829),
#  ('b2b_opp', 0.002007734958740488),
#  ('3p_opp_82', 0.0020035712753805135),
#  ('total_82', 0.001738367120665971),
#  ('pts_opp_82', 0.0015039283246261479),
#  ('fta_opp_82', 0.0014836692753798122),
#  ('pts_82', 0.00048293690864579825),
#  ('total_opp_82', 0.0003202879294698109),
#  ('usg%_82', 0.0),
#  ('usg%_opp_82', 0.0),
#  ('home', 0.0),
#  ('home_opp', 0.0)]

# %%
top_features = [feature[0] for feature in sorted_feature_importance[:30] if feature[1] > 0]
top_features
# Out:
# ['net_rtg_opp_82',
#  'net_rtg_82',
#  'won_82',
#  'won_opp_82',
#  'ast%_opp_82',
#  'ts%_82',
#  '3par_82',
#  'stl%_opp_82',
#  'drb_opp_82',
#  '3pa_opp_82',
#  'ortg_opp_82',
#  'b2b',
#  'fg%_82',
#  'ft%_82',
#  'blk_opp_82',
#  '3pa_82',
#  'orb%_82',
#  'ast_tov_82',
#  'tov%_opp_82',
#  'ast%_82',
#  'drb%_opp_82',
#  'stl%_82',
#  'ast_tov_opp_82',
#  'blk%_opp_82',
#  'pf_82',
#  'fg%_opp_82',
#  'drb%_82',
#  'blk%_82',
#  'trb%_82',
#  'pf_opp_82']

# %%
list1 = ['net_rtg_opp_82',
 'net_rtg_82',
 'won_82',
 'won_opp_82',
 'ts%_82',
 'ast%_opp_82',
 'drb_opp_82',
 '3par_82',
 'ft%_82',
 '3pa_82',
 'stl%_opp_82',
 'ortg_opp_82',
 'b2b',
 '3pa_opp_82',
 'fg%_82',
 'ast_tov_82',
 '3par_opp_82',
 'blk_opp_82',
 'orb%_82',
 'stl%_82',
 'trb_opp_82',
 'tov_opp_82',
 'drb%_82',
 'stl_opp_82',
 'tov%_opp_82',
 'blk%_opp_82',
 'drb%_opp_82',
 'drtg_82',
 'rb_diff_opp_82',
 'pf_opp_82']

list2 = ['net_rtg_opp_82',
 'net_rtg_82',
 'won_82',
 'won_opp_82',
 'ast%_opp_82',
 'ts%_82',
 '3par_82',
 'stl%_opp_82',
 'drb_opp_82',
 '3pa_opp_82',
 'ortg_opp_82',
 'b2b',
 'fg%_82',
 'ft%_82',
 'blk_opp_82',
 '3pa_82',
 'orb%_82',
 'ast_tov_82',
 'tov%_opp_82',
 'ast%_82',
 'drb%_opp_82',
 'stl%_82',
 'ast_tov_opp_82',
 'blk%_opp_82',
 'pf_82',
 'fg%_opp_82',
 'drb%_82',
 'blk%_82',
 'trb%_82',
 'pf_opp_82']

difference = set(list1) ^ set(list2)
print(list(difference))
# Out:
# ['trb_opp_82', 'pf_82', 'ast%_82', '3par_opp_82', 'blk%_82', 'drtg_82', 'ast_tov_opp_82', 'trb%_82', 'tov_opp_82', 'rb_diff_opp_82', 'stl_opp_82', 'fg%_opp_82']

# %%
team_df_processed=team_df[features_to_train + ["team", "team_opp", "date", "season", "won",]]

# %%
team_df_processed.to_csv("team_df_processed.csv")

# %%
team_df_top_features_processed = team_df[top_features + ["team", "team_opp", "date", "season", "won",]]

# %%
team_df_top_features_processed.to_csv("team_df_top_features_processed.csv")
